# %% [markdown]
# # CPUTemperature
# > a little widget for assessing the current temperature of the first
# > processor of a widget

# %%
from psutil import sensors_temperatures

with __import__("importnb").Notebook():
    from TemperatureSlider import TemperatureSlider, T, W

# %%
class CPUTemperatureSlider(TemperatureSlider):
    @T.default("value")
    def _default_temperature(self):
        return self.read_temperature()
    
    def read_temperature(self):
        return sensors_temperatures()["coretemp"][0].current
        
    @property
    def updated_value(self):
        self.value = self.read_temperature()
        return self.value

# %%
if __name__ == "__main__":
    temp = CPUTemperatureSlider()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Documents/projects/deathbeds/wxyz/envs/default/lib/python3.7/site-packages/traitlets/traitlets.py in get(self, obj, cls)
#     527         try:
# --> 528             value = obj._trait_values[self.name]
#     529         except KeyError:
#
# KeyError: 'value'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/Documents/projects/deathbeds/wxyz/envs/default/lib/python3.7/site-packages/traitlets/traitlets.py in get(self, obj, cls)
#     527         try:
# --> 528             value = obj._trait_values[self.name]
#     529         except KeyError:
#
# KeyError: 'value'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
    # %reload_ext pidgin

# %%
# RIGHT SIDE OF THE TRACKS
# Out:
# <a href="#RIGHT-SIDE-OF-THE-TRACKS"><h1 id="RIGHT-SIDE-OF-THE-TRACKS">RIGHT SIDE OF THE TRACKS</h1></a>

# %%
# $1/2$ the ⏰
# $1/2$ the 💰
# Out:
# <a href="#1-2-the"><h1 id="1-2-the">$1/2$ the ⏰</h1></a><a href="#1-2-the"><h1 id="1-2-the">$1/2$ the 💰</h1></a>

# %%
## How do 👨‍🍳👩‍🚀👩‍🎨💂👷‍♀️💃 get there⁉️
# Out:
# <a href="#How-do-get-there"><h2 id="How-do-get-there">How do 👨‍🍳👩‍🚀👩‍🎨💂👷‍♀️💃 get there⁉️</h2></a>

# %%
digraph {
    rankdir=LR
    Prescriptive -> Predictive [label=SKRUD]
    "Opaque Types" -> "Semantic Types"[label=SKRUD]
    "Context independent" -> "Context dependent"[label=SKRUD]
    "Create models" -> "Apply models"[label=SKRUD]
    "Information Systems" -> "Knowledge Systems"[label=SKRUD]
    "Past" -> "Future"[label=SKRUD]
}
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
# <!-- Generated by graphviz version 2.38.0 (20140413.2041)
#  -->
# <!-- Title: %3 Pages: 1 -->
# <svg width="425pt" height="314pt"
#  viewBox="0.00 0.00 424.68 314.00" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g id="graph0" class="graph" transform="scale(1 1) rotate(0) translate(4 310)">
# <title>%3</title>
# <polygon fill="white" stroke="none" points="-4,4 -4,-310 420.675,-310 420.675,4 -4,4"/>
# <!-- Prescriptive -->
# <g id="node1" class="node"><title>Prescriptive</title>
# <ellipse fill="none" stroke="black" cx="84.0413" cy="-18" rx="52.1934" ry="18"/>
# <text text-anchor="middle" x="84.0413" y="-13.8" font-family="Times,serif" font-size="14.00">Prescriptive</text>
# </g>
# <!-- Predictive -->
# <g id="node2" class="node"><title>Predictive</title>
# ...

# %%
# 🚜💻🖥 NEVER LEARN‼️

> ## I've written so many lines of code of the same ~~DARN~~ code
> ### and the `"computer"` never learns.

![](https://memegenerator.net/img/instances/80816644.jpg)
# Out:
# <a href="#NEVER-LEARN"><h1 id="NEVER-LEARN">🚜💻🖥 NEVER LEARN‼️</h1></a><blockquote><a href="#I-ve-written-so-many-lines-of-code-of-the-same-del-DARN-del-code"><h2 id="I-ve-written-so-many-lines-of-code-of-the-same-del-DARN-del-code">I've written so many lines of code of the same <del>DARN</del> code</h2></a><a href="#and-the-span-class-highlight-code-style-display-inline-block-vertical-align-middle-line-height-125-span-span-span-style-color-BA2121-computer-span-code-span-never-learns"><h3 id="and-the-span-class-highlight-code-style-display-inline-block-vertical-align-middle-line-height-125-span-span-span-style-color-BA2121-computer-span-code-span-never-learns">and the <span class="highlight"><code style="display: inline-block; vertical-align: middle; line-height: 125%"><span></span><span style="color: #BA2121">&quot;computer&quot;</span>
# </code></span> never learns.</h3></a>
# </blockquote>
# <p><img src="https://memegenerator.net/img/instances/80816644.jpg" alt=""></p>

# %%
### LESS IS MORE
# 🖐🏼⌨️

> We should be able to do more with a keypress.
# Out:
# <a href="#LESS-IS-MORE"><h3 id="LESS-IS-MORE">LESS IS MORE</h3></a><a href="#"><h1 id="">🖐🏼⌨️</h1></a><blockquote><p>We should be able to do more with a keypress.</p>
# </blockquote>

# %%
* ## [🍪🍪🍪🍪🍪🍪🍪🍪🍪🍪](cookies.ipynb)
* ## [🖼📈📊🖼](dataframe_widget.ipynb)
# Out:
# <ul>
# <li><a href="#a-href-cookies-ipynb-a"><h2 id="a-href-cookies-ipynb-a"><a href="cookies.ipynb">🍪🍪🍪🍪🍪🍪🍪🍪🍪🍪</a></h2></a></li>
# <li><a href="#a-href-dataframe-widget-ipynb-a"><h2 id="a-href-dataframe-widget-ipynb-a"><a href="dataframe_widget.ipynb">🖼📈📊🖼</a></h2></a></li>
# </ul>
